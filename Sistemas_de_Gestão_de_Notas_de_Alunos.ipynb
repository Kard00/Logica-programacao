# %% [markdown]
# <a href="https://colab.research.google.com/github/Kard00/Logica-programacao/blob/main/Sistemas_de_Gest%C3%A3o_de_Notas_de_Alunos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def apurador_notas(): # criação de função sem parâmetros (não precisa do return nesse caso).

  print("-" * 39) # formatação para deixar uma cara amigavel.
  print("        ***APURADOR DE NOTAS*** \n\nSeja bem vindo(a) ao sistema de apuração \nde notas.\n \nInsira as suas notas para saber a média \ne a sua situação ao final de cada \nperíodo do curso \"Ciência de dados.\" ")
  print("-" * 39)

  notas = [] # Lista para armazernar as notas inseridas pelo usuário.
  while len(notas) < 5: # laço de repetição que conta e limita aquantidade de entrada feita pelo usuário.
    try:
        # Recebe dado como texto e conta quantos dados foram inseridos (quando chegar no limite (5), o laço para)
        entrada = input(f"Digite a {len(notas) + 1}ª nota (de 0 a 10): ")

        # Troca vírgula por ponto para evitar erros caso o usuário digite "7,5" em vez de "7.5"
        entrada = entrada.replace(',', '.')

        # Converte a entradad de dado (texto) para número decimal (float)
        nota = float(entrada)

        # Verifica se a nota está dentro do limite de 0 a 10
        if 0 <= nota <= 10: # condicional para limitar o tamanho máximo de uma nota.
            notas.append(nota) # Se estiver tudo certo, adiciona na lista!
        else: # o usuário digitou qualquer coisa, menos o pedido, então, gera o erro.
            print("Erro: A nota deve ser um valor entre 0 e 10. Tente novamente.\n")

    except ValueError:
        # Tem que ver que tipo de erro dá para poder colocar no except e ser um erro rastreável e corrigível.
        # except é usado para não crashar o sistema, mas poder tratar o erro.
        print("Erro: Entrada inválida! Por favor, digite apenas números.\n")
  # Fórmula da média.
  media = sum(notas) / len(notas)
  # Condicional para saber a situação do(a) aluno(a)
  if media >= 7:# média maior ou igual á 7.
      aluno = "aprovado(a)"
      print(f"\nA sua média é: {media:.2f}, portanto, o(a) aluno(a) está {aluno}. \nParabéns!")
  else:
      aluno = "reprovado(a)"
      print(f"\nA sua média é: {media:.2f}, portanto, o(a) aluno(a) está {aluno}. \nNão desista, amanhã é um novo dia para tentar mais uma vez!")

  notas_formatadas = str(notas)[1:-1] # Retirando o "[ ]" para mostrar somente as notas.

  print("-" * 39)
  print("          ***RELATÓRIO***        ")
  print("-" * 39)
  print(f"Essas são as suas notas nesse período: {notas_formatadas} . ")
  print(f"A sua média é: {media: .2f}")
  print(f"A sua situação é: {aluno}.")
  print("-" * 39)
apurador_notas() # chamando a função
# Out:
# ---------------------------------------
#         ***APURADOR DE NOTAS***
#
# Seja bem vindo(a) ao sistema de apuração
# de notas.
#
# Insira as suas notas para saber a média
# e a sua situação ao final de cada
# período do curso "Ciência de dados."
# ---------------------------------------
# Digite a 1ª nota (de 0 a 10): T
# Erro: Entrada inválida! Por favor, digite apenas números.
#
# Digite a 1ª nota (de 0 a 10): @
# Erro: Entrada inválida! Por favor, digite apenas números.
#
# Digite a 1ª nota (de 0 a 10): \
# Erro: Entrada inválida! Por favor, digite apenas números.
#
# Digite a 1ª nota (de 0 a 10): sete
# Erro: Entrada inválida! Por favor, digite apenas números.
#
# Digite a 1ª nota (de 0 a 10): 5,6
# Digite a 2ª nota (de 0 a 10): 2.e
# Erro: Entrada inválida! Por favor, digite apenas números.
#
# Digite a 2ª nota (de 0 a 10): O
# Erro: Entrada inválida! Por favor, digite apenas números.
#
# Digite a 2ª nota (de 0 a 10): 0
# Digite a 3ª nota (de 0 a 10): 9.0
# ...

# %%
# criando um conjunto vazio
meu_conjunto = set()

meu_conjunto.add(10)
meu_conjunto.add(20)
meu_conjunto.add(30)
# imprimindo o conjunto atualizado
print('Esse é o meu conjunto após adicionar elementos. ', meu_conjunto)
# verificando se o elemento está no conjunto
elemento = 20
if elemento in meu_conjunto:
    print(f'O elemento {elemento} está no conjunto.')
else:
  print(f' O elemento {elemento} não está no conjunto. ')
# removendo um elemento do conjunto
meu_conjunto.remove(20)
print("Conjunto após remover o elemento 20. ", meu_conjunto)
# Out:
# Esse é o meu conjunto após adicionar elementos.  {10, 20, 30}
# O elemento 20 está no conjunto.
# Conjunto após remover o elemento 20.  {10, 30}

# %%
# Criando um dicionário vazio
dici_1 = {}
# atribuindo valores ao dicionário
dici_1['nome'] = "Maria"
dici_1['idade'] = 25
print(dici_1)
# Out:
# {'nome': 'Maria', 'idade': 25}

# %%
# Criando dicionário com pares    chave: valor
dici_2 = {'nome': 'Maria', 'idade': 25}
print(dici_2)
# Out:
# {'nome': 'Maria', 'idade': 25}

# %%
# *** Início da correção ***
# Deletando a variável 'dict' que está sombreando o construtor 'dict' built-in.
# Isso permite que o código use a função 'dict' corretamente.
if 'dict' in globals():
    del dict
# *** Fim da correção ***

# criando dicionário com uma lista de tuplas representando pares chave: valor
dici_3 = dict([('nome', 'Maria'), ('idade', 25)])
print(dici_3)
# Out:
# {'nome': 'Maria', 'idade': 25}

# %%
# criando dicionário com a função built-in zip() e duas listas, uma para as chaves e a outra para os valores
dici_4 = dict(zip(['nome', 'idade'], ['Maria', 25]))
print(dici_4)
# Out:
# {'nome': 'Maria', 'idade': 25}

# %%
print(dici_1 == dici_2 == dici_3 == dici_4)
print(dici_1)
# Out:
# True
# {'nome': 'Maria', 'idade': 25}

# %%
# importe a bíblioteca numpy
import numpy as np
# crie um array numpy de números inteiros
my_array = np.array([1, 2, 3, 4, 5])
# imprima oa array
print("Array original:")
print(my_array)
# Out:
# Array original:
# [1 2 3 4 5]

# %%
# Realize operações matemáticas com o array
squared_array = my_array ** 2 # eleva cada elemento ao quadrado
sum_of_elements = np.sum(my_array) # soma todos os elementos do array

# %%
# imprima os resultados
print("Array ao quadrado:")
print(squared_array)
print("Soma dos elementos do array:")
print(sum_of_elements)
# Out:
# Array ao quadrado:
# [ 1  4  9 16 25]
# Soma dos elementos do array:
# 15

# %%
# acesse os elementos do array
element_at_index_2 = my_array[2]
print("Elemento no índice 2: ", element_at_index_2)
# Out:
# Elemento no índice 2:  3

# %%
# Define uma classe chamada Pessoa.
class Pessoa:
    # O método __init__ é um construtor, chamado quando um objeto da classe é criado.
    # Ele inicializa os atributos da classe.
    def __init__(self, nome, idade, genero):
        # self é uma convenção em Python que se refere à própria instância da classe.
        # Os parâmetros nome, idade e gênero são passados durante a criação do objeto.
        # Eles são usados para inicializar os atributos da instância.
        self.nome = nome  # Atribui o valor de nome ao atributo nome da instância.
        self.idade = idade  # Atribui o valor de idade ao atributo idade da instância.
        self.genero = genero  # Atribui o valor de gênero ao atributo gênero da instância.
    # O método cumprimentar retorna uma saudação com o nome da pessoa.
    def cumprimentar(self):
        return f"Olá, meu nome é {self.nome}."
    # O método aniversário aumenta a idade da pessoa em 1.
    def aniversario(self):
        self.idade += 1
# Cria uma instância da classe “Pessoa” com os valores “João”, 30 e “Masculino” para nome, idade e gênero, respectivamente.
pessoa1 = Pessoa("João", 30, "Masculino")
# Chama o método “cumprimentar” na instância pessoa1 e imprime a saudação.
print(pessoa1.cumprimentar())  # Saída: “Olá, meu nome é João.”
# Acessa o atributo idade da instância pessoa1 e imprime sua idade.
print(f"Idade: {pessoa1.idade}")  # Saída: “Idade: 30”
# Chama o método “aniversário” na instância pessoa1 para aumentar sua idade em 1.
pessoa1.aniversario()
# Acessa o atributo idade atualizado da instância pessoa1 e imprime a nova idade.
print(f"Nova idade: {pessoa1.idade}")  # Saída: “Nova idade: 31”
# Out:
# Olá, meu nome é João.
# Idade: 30
# Nova idade: 31

# %%
class animal:
  def __init__(self, nome) -> None:
      self.nome = nome
  def fazer_barulho(self):
        pass
class Cachorro(animal):
  def fazer_barulho(self):
      return "latir"
class Gato(animal):
  def fazer_barulho(self):
      return "Miar"

# %%
rex = Cachorro("Rex")
whiskers = Gato("Whiskers")

# %%
print(f'{rex.nome} faz {rex.fazer_barulho()}')
print(f'{whiskers.nome} faz : {whiskers.fazer_barulho()}')
# Out:
# Rex faz latir
# Whiskers faz : Miar

# %%
class Veiculo:
    def __init__(self, marca, modelo, ano):
        self.marca = marca
        self.modelo = modelo
        self.ano = ano
        self.velocidade = 0

    def acelerar(self, incremento):
        self.velocidade += incremento

    def frear(self, decremento):
        self.velocidade -= decremento

    def status(self):
        return f"Marca: {self.marca}, Modelo: {self.modelo}, Ano: {self.ano}, Velocidade: {self.velocidade} km/h"

class Carro(Veiculo):
    def __init__(self, marca, modelo, ano, potencia):
        super().__init__(marca, modelo, ano)
        self.potencia = potencia

    def acelerar(self, incremento):
        # Carros podem acelerar mais rápido.
        self.velocidade += incremento + self.potencia

class Bicicleta(Veiculo):
    def __init__(self, marca, modelo, ano, tipo):
        super().__init__(marca, modelo, ano)
        self.tipo = tipo

    def status(self):
        return f"Marca: {self.marca}, Modelo: {self.modelo}, Ano: {self.ano}, Tipo: {self.tipo}, Velocidade: {self.velocidade} km/h"

# Criando objetos
carro1 = Carro("Toyota", "Corolla", 2022, 150)
bicicleta1 = Bicicleta("Trek", "Mountain Bike", 2021, "MTB")

# Acelerando e verificando o status
carro1.acelerar(50)
bicicleta1.acelerar(20)

# Exibindo o status dos veículos
print("Status do Carro:")
print(carro1.status())

print("\nStatus da Bicicleta:")
print(bicicleta1.status())
# Out:
# Status do Carro:
# Marca: Toyota, Modelo: Corolla, Ano: 2022, Velocidade: 200 km/h
#
# Status da Bicicleta:
# Marca: Trek, Modelo: Mountain Bike, Ano: 2021, Tipo: MTB, Velocidade: 20 km/h

# %%
numeros = [3, 7, 2, 8, 4, 1, 9, 5, 6]

# %%
numeros.reverse()

# %%
numeros.sort()

# %%
numeros.append(10)

# %%
numeros.remove(4)

# %%
print(numeros)
# Out:
# [1, 2, 3, 5, 6, 7, 8, 9, 10]

# %%
import matplotlib.pyplot as plt
# Dados de exemplo
meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio']
vendas = [120, 90, 150, 80, 200]
# Criar um gráfico de barras
plt.bar(meses, vendas, color='royalblue')
# Adicionar rótulos aos eixos
plt.xlabel('Mês')
plt.ylabel('Vendas (em unidades)')
# Adicionar um título ao gráfico
plt.title('Vendas Mensais')
# Mostrar o gráfico

plt.show()

# %%
# primeiro modo
import math

# math.sqrt(25)
# math.log2(1024)
math.cos(45)
# Out:
# 0.5253219888177297

# %%
# segundo modo
import math as m
m.sqrt(25)
# m.log2(1024)
# m.cos(45)
# Out:
# 5.0

# %%
# terceiro modo
from math import sqrt, log2, cos
# sqrt(25)
log2(1024)
# cos(45)
# Out:
# 10.0

# %%
import matplotlib.pyplot as plt

# %%
# dados
x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]

# %%
# criar um gráfico
plt.plot(x, y)

# %%
# adicionar róyulos aos eixos  x e y
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
# Out:
# Text(0, 0.5, 'Eixo y')

# %%
# adicionar um título ao gráfico
plt.title ("Exemplo de gráfico de linha")
# Out:
# Text(0.5, 1.0, 'Exemplo de gráfico de linha')

# %%
# mostrar o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
# dados
x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]
# criar um gráfico
plt.plot(x, y)
# adicionar róyulos aos eixos  x e y
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
# adicionar um título ao gráfico
plt.title ("Exemplo de gráfico de linha")
# mostrar o gráfico
plt.show()
